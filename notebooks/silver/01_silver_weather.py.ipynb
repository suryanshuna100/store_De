# %% [markdown]
# ##Read Bronze Data

# %%
df = (
    spark.read
    .option("multiline", "true")
    .json(
        "s3://weather-data-pipeline-235/bronze/weather/"
    )
)

# %% [markdown]
# ## import required func

# %%
from pyspark.sql.functions import (
    col,
    to_timestamp,
    to_date,
    when
)

# %% [markdown]
# ##Standardize Data Types

# %%
df = (
    df
    .withColumn(
        "humidity",
        col("humidity").cast("integer")
    )
    .withColumn(
        "pressure",
        col("pressure").cast("integer")
    )
    .withColumn(
        "temperature",
        col("temperature").cast("double")
    )
    .withColumn(
        "wind_speed",
        col("wind_speed").cast("double")
    )
)

# %% [markdown]
# ##Create Timestamp Column

# %%
df = (
    df
    .withColumn(
        "ingestion_ts",
        to_timestamp(
            "ingestion_timestamp"
        )
    )
)

# %% [markdown]
# ##create date column

# %%
df = (
    df
    .withColumn(
        "ingestion_date",
        to_date(
            "ingestion_ts"
        )
    )
)

# %% [markdown]
# ##Create temperature category

# %%
df = (
    df
    .withColumn(
        "temperature_category",
        when(
            col("temperature") < 15,
            "Cold"
        )
        .when(
            col("temperature") < 30,
            "Moderate"
        )
        .otherwise(
            "Hot"
        )
    )
)

# %% [markdown]
# ##create humidity category

# %%
df = (
    df
    .withColumn(
        "humidity_category",
        when(
            col("humidity") < 40,
            "Dry"
        )
        .when(
            col("humidity") < 70,
            "Normal"
        )
        .otherwise(
            "Humid"
        )
    )
)

# %% [markdown]
# ##create wind category

# %%
df = (
    df
    .withColumn(
        "wind_category",
        when(
            col("wind_speed") < 3,
            "Low"
        )
        .when(
            col("wind_speed") < 8,
            "Medium"
        )
        .otherwise(
            "High"
        )
    )
)

# %%
df.filter(
    col("city").isNull()
).show()

# %%
df.filter(
    col("temperature").isNull()
).show()

# %%
df.printSchema()

# %%
silver_path = (
    "s3://weather-data-pipeline-235/silver/weather/"
)

# %%
(
    df.write
    .format("delta")
    .mode("overwrite")
    .partitionBy(
        "year",
        "month",
        "day"
    )
    .save(
        silver_path
    )
)

# %% [markdown]
# Why partition? Future queries: SELECT * FROM silver_weather WHERE year=2026 AND month=06 AND day=05 will scan only required partitions.

# %%
silver_df = (
    spark.read
    .format("delta")
    .load(
        silver_path
    )
)

# %%
display(silver_df.limit(5))

# %%
silver_df.printSchema()
